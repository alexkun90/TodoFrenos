-- %% [markdown]
-- # [TallerTodoFrenos]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TallerTodoFrenos]    Script Date: 21/05/2024 16:10:30 ******/
CREATE DATABASE [TallerTodoFrenos]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TallerTodoFrenos', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\TallerTodoFrenos.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TallerTodoFrenos_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\TallerTodoFrenos_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [TallerTodoFrenos] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TallerTodoFrenos].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TallerTodoFrenos] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET ARITHABORT OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TallerTodoFrenos] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TallerTodoFrenos] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TallerTodoFrenos] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TallerTodoFrenos] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [TallerTodoFrenos] SET  MULTI_USER 
GO
ALTER DATABASE [TallerTodoFrenos] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TallerTodoFrenos] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TallerTodoFrenos] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TallerTodoFrenos] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TallerTodoFrenos] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TallerTodoFrenos] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [TallerTodoFrenos] SET QUERY_STORE = ON
GO
ALTER DATABASE [TallerTodoFrenos] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [DataHouse]

-- %%
USE [TallerTodoFrenos]
GO

-- %%
/****** Object:  User [DataHouse]    Script Date: 21/05/2024 16:10:31 ******/
CREATE USER [DataHouse] FOR LOGIN [DataHouse] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [AlexData]

-- %%
/****** Object:  User [AlexData]    Script Date: 21/05/2024 16:10:31 ******/
CREATE USER [AlexData] FOR LOGIN [AlexData] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [DataHouse]

-- %%
ALTER ROLE [db_datareader] ADD MEMBER [DataHouse]
GO
ALTER ROLE [db_datawriter] ADD MEMBER [DataHouse]
GO

-- %% [markdown]
-- # [AlexData]

-- %%
ALTER ROLE [db_owner] ADD MEMBER [AlexData]
GO
ALTER ROLE [db_datareader] ADD MEMBER [AlexData]
GO
ALTER ROLE [db_datawriter] ADD MEMBER [AlexData]
GO

-- %% [markdown]
-- # [dbo].[Carrito]

-- %%
/****** Object:  Table [dbo].[Carrito]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Carrito](
	[IdCarrito] [int] IDENTITY(1,1) NOT NULL,
	[IdUser] [int] NULL,
	[IdProducto] [int] NULL,
	[PrecioTotal] [decimal](10, 2) NULL,
	[Cantidad] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdCarrito] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Citas]

-- %%
/****** Object:  Table [dbo].[Citas]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Citas](
	[IdCitas] [int] IDENTITY(1,1) NOT NULL,
	[IdUser] [int] NULL,
	[NumeroTel] [nvarchar](20) NULL,
	[IdVehiculo] [int] NULL,
	[FechaCita] [date] NULL,
	[FechaCreacion] [datetime] NULL,
	[FechaModificacion] [datetime] NULL,
	[Motivo] [nvarchar](255) NULL,
	[Estado] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdCitas] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DetalleFactura]

-- %%
/****** Object:  Table [dbo].[DetalleFactura]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetalleFactura](
	[IdFactura] [int] NULL,
	[Descripcion] [nvarchar](max) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Factura]

-- %%
/****** Object:  Table [dbo].[Factura]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Factura](
	[IdFactura] [int] IDENTITY(1,1) NOT NULL,
	[IdCarrito] [int] NULL,
	[FechaFactura] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[IdFactura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
/****** Object:  Table [dbo].[Productos]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Productos](
	[IdProducto] [int] IDENTITY(1,1) NOT NULL,
	[IdCategory] [int] NULL,
	[Name] [nvarchar](100) NULL,
	[URL_Image] [nvarchar](max) NULL,
	[Stock] [int] NULL,
	[Precio] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdProducto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[IdRol] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NULL,
	[NormalizedName] [nvarchar](50) NULL,
	[ConcurrencyStamp] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdRol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserRoles]

-- %%
/****** Object:  Table [dbo].[UserRoles]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserRoles](
	[UserId] [int] NOT NULL,
	[RoleId] [int] NOT NULL,
 CONSTRAINT [PK_UserRoles] PRIMARY KEY CLUSTERED 
(
	[UserId] ASC,
	[RoleId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[IdUsuario] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [nvarchar](50) NULL,
	[NormalizedUserName] [nvarchar](50) NULL,
	[Email] [nvarchar](100) NULL,
	[Cedula] [nvarchar](20) NULL,
	[NormalizedEmail] [nvarchar](100) NULL,
	[EmailConfirmed] [bit] NULL,
	[PasswordHash] [nvarchar](max) NULL,
	[SecurityStamp] [nvarchar](max) NULL,
	[ConcurrencyStamp] [nvarchar](max) NULL,
	[PhoneNumber] [nvarchar](20) NULL,
	[PhoneNumberConfirmed] [bit] NULL,
	[TwoFactorEnabled] [bit] NULL,
	[LockoutEnd] [datetimeoffset](7) NULL,
	[LockoutEnabled] [bit] NULL,
	[AccessFailedCount] [int] NULL,
	[Nombre] [nvarchar](50) NULL,
	[PrimApellido] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Vehiculo]

-- %%
/****** Object:  Table [dbo].[Vehiculo]    Script Date: 21/05/2024 16:10:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Vehiculo](
	[IdVehiculo] [int] IDENTITY(1,1) NOT NULL,
	[IdUser] [int] NULL,
	[Marca] [nvarchar](50) NULL,
	[Matricula] [nvarchar](20) NULL,
	[FechaCreacion] [datetime] NULL,
	[Estado] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[IdVehiculo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Carrito_Productos]

-- %%
ALTER TABLE [dbo].[Carrito]  WITH CHECK ADD  CONSTRAINT [FK_Carrito_Productos] FOREIGN KEY([IdProducto])
REFERENCES [dbo].[Productos] ([IdProducto])
GO
ALTER TABLE [dbo].[Carrito] CHECK CONSTRAINT [FK_Carrito_Productos]
GO

-- %% [markdown]
-- # [FK_Carrito_Usuarios]

-- %%
ALTER TABLE [dbo].[Carrito]  WITH CHECK ADD  CONSTRAINT [FK_Carrito_Usuarios] FOREIGN KEY([IdUser])
REFERENCES [dbo].[Usuarios] ([IdUsuario])
GO
ALTER TABLE [dbo].[Carrito] CHECK CONSTRAINT [FK_Carrito_Usuarios]
GO

-- %% [markdown]
-- # [FK_Citas_Usuarios]

-- %%
ALTER TABLE [dbo].[Citas]  WITH CHECK ADD  CONSTRAINT [FK_Citas_Usuarios] FOREIGN KEY([IdUser])
REFERENCES [dbo].[Usuarios] ([IdUsuario])
GO
ALTER TABLE [dbo].[Citas] CHECK CONSTRAINT [FK_Citas_Usuarios]
GO

-- %% [markdown]
-- # [FK_Citas_Vehiculo]

-- %%
ALTER TABLE [dbo].[Citas]  WITH CHECK ADD  CONSTRAINT [FK_Citas_Vehiculo] FOREIGN KEY([IdVehiculo])
REFERENCES [dbo].[Vehiculo] ([IdVehiculo])
GO
ALTER TABLE [dbo].[Citas] CHECK CONSTRAINT [FK_Citas_Vehiculo]
GO

-- %% [markdown]
-- # [FK_DetalleFactura_Factura]

-- %%
ALTER TABLE [dbo].[DetalleFactura]  WITH CHECK ADD  CONSTRAINT [FK_DetalleFactura_Factura] FOREIGN KEY([IdFactura])
REFERENCES [dbo].[Factura] ([IdFactura])
GO
ALTER TABLE [dbo].[DetalleFactura] CHECK CONSTRAINT [FK_DetalleFactura_Factura]
GO

-- %% [markdown]
-- # [FK_Factura_Carrito]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD  CONSTRAINT [FK_Factura_Carrito] FOREIGN KEY([IdCarrito])
REFERENCES [dbo].[Carrito] ([IdCarrito])
GO
ALTER TABLE [dbo].[Factura] CHECK CONSTRAINT [FK_Factura_Carrito]
GO

-- %% [markdown]
-- # [FK_UserRoles_Roles]

-- %%
ALTER TABLE [dbo].[UserRoles]  WITH CHECK ADD  CONSTRAINT [FK_UserRoles_Roles] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([IdRol])
GO
ALTER TABLE [dbo].[UserRoles] CHECK CONSTRAINT [FK_UserRoles_Roles]
GO

-- %% [markdown]
-- # [FK_UserRoles_Usuarios]

-- %%
ALTER TABLE [dbo].[UserRoles]  WITH CHECK ADD  CONSTRAINT [FK_UserRoles_Usuarios] FOREIGN KEY([UserId])
REFERENCES [dbo].[Usuarios] ([IdUsuario])
GO
ALTER TABLE [dbo].[UserRoles] CHECK CONSTRAINT [FK_UserRoles_Usuarios]
GO

-- %% [markdown]
-- # [TallerTodoFrenos]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TallerTodoFrenos] SET  READ_WRITE 
GO
